# %% [markdown]
# # Train P-Net
# - 10000 train images, 3466 eval images
# - EPOCH = 30
# - LR = 0.001
# - batch size = 32
# - num of worker = 8
# - loss configuration: 1.0 for label, 0.5 for offset， 0.5 for landmark

# %%
import torch
import torch.nn as nn
import torch.optim as opt
import torchvision
from torchvision import transforms
import torch.utils.data as data
from torch.utils.data import DataLoader
import torchvision.transforms.functional as tf
from PIL import Image
import os.path as osp
import numpy as np
from numpy.random import uniform
import PIL
from PIL import Image, ImageDraw
from random import shuffle
import matplotlib.pyplot as plt
import seaborn as sns
import time
import math
import random
import argparse
import os
import copy
import json
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## PnetDataset: gives both boxes and landmarks

# %%
def IoU(box, face):

    box_area = (box[2] - box[0] + 1) * (box[3] - box[1] + 1)
    area = (face[2] - face[0] + 1) * (face[3] - face[1] + 1)

    xx1 = np.maximum(box[0], face[0])
    yy1 = np.maximum(box[1], face[1])
    xx2 = np.minimum(box[2], face[2])
    yy2 = np.minimum(box[3], face[3])

    w = np.maximum(0, xx2 - xx1 + 1)
    h = np.maximum(0, yy2 - yy1 + 1)

    inter = w * h
    ovr = inter / (box_area + area - inter)
    return ovr

# %%
setdic = {'train': 10000, 'test': 3466}
root = '../input/facial-point-detection/Facial_Point_Detection/'

class PnetDataset(data.Dataset):
    def __init__(self, phase, num_images, ratio=(1, 1, 1, 1)):
        
        self.length = num_images
        ratio_sum = float(sum(ratio))
        self.ratio = [i / ratio_sum for i in ratio]
        self.images = []
        self.boxes = []
        self.landmarks = []
        
        file = open(root + phase +'ImageList.txt')
        lines = file.readlines()
        
        for line in lines:
            line = line.strip()
            contents = line.split()
            name = contents[0]
            box = contents[1:5]
            landmark = contents[5:]
            image_full_path = root + name.replace('\\', '/')
            
            try:
                img = Image.open(image_full_path)
            except:
                print(image_full_path)
                continue
            self.images.append(image_full_path)
            self.boxes.append([int(i) for i in box])
            self.landmarks.append([float(i) for i in landmark])    
    
    
    def get_crop_img_label_offset_ldmk(self, img, face, ldmk):
        def get_crop_img(img_np, crop_box):
            crop_box = [int(i) for i in crop_box]
            crop_img_np = img_np[crop_box[1]:crop_box[3], crop_box[0]:crop_box[2], :]
            crop_img = Image.fromarray(crop_img_np, mode='RGB')
            crop_img = crop_img.resize((12,12), resample=PIL.Image.BILINEAR)
            return crop_img


        def cal_offset(face, box):
            if box is None:
                return []
            offset = [
                (face[0] - box[0]) / float(box[2] - box[0]),
                (face[1] - box[1]) / float(box[3] - box[1]),
                (face[2] - box[2]) / float(box[2] - box[0]),
                (face[3] - box[3]) / float(box[3] - box[1]),
            ]
            return offset

        
        def cal_landmark_offset(box, ldmk):
            minx, miny = box[0], box[1]
            w, h = box[2] - box[0], box[3] - box[1]
            ldmk_offset = [(ldmk[i] - [minx, miny][i % 2]) / float([w, h][i % 2]) for i in range(len(ldmk))]
            return ldmk_offset
        
        
        face = np.array([face[0],face[2],face[1],face[3]])
        
        img_np = np.array(img)
        width, height = img.size
        
        label = np.random.choice(['n', 'np', 'pf', 'p'], p=self.ratio)
        iou_th = {'n': (0, 0.3), 'np': (0, 0.3), 'pf': (0.4, 0.65), 'p': (0.65, 1.0)}.get(label)
        sigma = {'n': 1, 'np': 0.3, 'pf': 0.1, 'p': 0.02}.get(label)
        

        face_max_size = max(face[2] - face[0], face[3] - face[1])
        
        max_size = min(width, height)
        
        crop_img = None
        crop_box = None
        
        for i in range(10):
            size = (uniform(-1.0, 1.0) * sigma + 1) * face_max_size
            size = min(max(12, size), max_size)
            x1, y1 = face[0], face[1]
            crop_x1, crop_y1 = (uniform(-1.0, 1.0) * sigma + 1) * x1, (uniform(-1.0, 1.0) * sigma + 1) * y1
            crop_x1, crop_y1 = min(max(0, crop_x1), width - size), min(max(0, crop_y1), height - size)
            crop_box = np.array([int(crop_x1), int(crop_y1), int(crop_x1 + size), int(crop_y1 + size)])
            iou = IoU(crop_box, face)

            if iou < iou_th[0] or iou > iou_th[1]:
                continue
            else:
                crop_img = get_crop_img(img_np, crop_box)
                break
                
        return crop_img, label, cal_offset(face, crop_box), cal_landmark_offset(crop_box, ldmk)


    def __getitem__(self, index):
        
        index = random.randint(0,len(self.images)-1)
        img = Image.open(self.images[index])
        face = self.boxes[index]
        ldmk = self.landmarks[index]
        crop_img, label, offset, ldmk = self.get_crop_img_label_offset_ldmk(img, face, ldmk)
        
        if crop_img is None: return self.__getitem__(0)
        
        img_tensor = transforms.ToTensor()(crop_img)
        label = torch.FloatTensor([1.0 if label in ['p', 'pf'] else 0.0])
        offset = torch.FloatTensor(offset)
        landmark = torch.FloatTensor(ldmk)
        
        return (img_tensor, label, offset, label, landmark)
    
    
    def __len__(self):
        return self.length

# %% [markdown]
# ## P-Net and customized loss function

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight.data)
        nn.init.constant_(m.bias, 0.1)
        

class P_Net(nn.Module):
    def __init__(self):
        super(P_Net, self).__init__()
        self.pre_layer = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=3, stride=1),
            nn.PReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(10, 16, kernel_size=3, stride=1),
            nn.PReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=1),
            nn.PReLU()
        )
        self.conv4_1 = nn.Conv2d(32, 1, kernel_size=1, stride=1)
        self.conv4_2 = nn.Conv2d(32, 4, kernel_size=1, stride=1)
        self.conv4_3 = nn.Conv2d(32, 10, kernel_size=1, stride=1,)
        self.apply(weights_init)

        
    def forward(self, x):
        x = self.pre_layer(x)
        det = torch.sigmoid(self.conv4_1(x))
        box = self.conv4_2(x)
        landmark = self.conv4_3(x)
        return det, box, landmark

# %%
class LossFn:
    def __init__(self, cls_factor=1, box_factor=1, landmark_factor=1):

        self.cls_factor = cls_factor
        self.box_factor = box_factor
        self.land_factor = landmark_factor
        self.loss_cls = nn.BCELoss()
        self.loss_box = nn.MSELoss()
        self.loss_landmark = nn.MSELoss()


    def cls_loss(self, gt_label, pred_label):
        
        pred_label = torch.squeeze(pred_label)
        gt_label = torch.squeeze(gt_label)
        mask = torch.ge(gt_label, 0)        
        valid_gt_label = gt_label[mask]
        valid_pred_label = pred_label[mask]
        
        return self.loss_cls(valid_pred_label, valid_gt_label) * self.cls_factor
    
    
    def box_loss(self, gt_label, gt_offset, pred_offset):

        pred_offset = torch.squeeze(pred_offset)
        gt_offset = torch.squeeze(gt_offset)
        gt_label = torch.squeeze(gt_label)
        mask = torch.eq(gt_label, 1)
        
        valid_gt_offset = gt_offset[mask, :]
        valid_pred_offset = pred_offset[mask, :]
        valid_sample_num = valid_gt_offset.shape[0]
        
        if 0 == valid_sample_num:
            return torch.tensor([0.0])
        else:
            return self.loss_box(valid_pred_offset, valid_gt_offset) * self.box_factor

        
    def landmark_loss(self, landmark_flag, gt_landmark=None, pred_landmark=None):
        pred_landmark = torch.squeeze(pred_landmark)
        gt_landmark = torch.squeeze(gt_landmark)
        gt_label = torch.squeeze(landmark_flag)
        mask = torch.eq(gt_label, 1)
        valid_gt_landmark = gt_landmark[mask, :]
        valid_pred_landmark = pred_landmark[mask, :]
        valid_sample_num = valid_gt_landmark.shape[0]
        if 0 == valid_sample_num:
            return torch.tensor([0.0])
        else:
            return self.loss_landmark(valid_pred_landmark, valid_gt_landmark) * self.land_factor

        
    def total_loss(self, gt_label, pred_label, gt_offset, pred_offset, landmark_flag, gt_landmark, pred_landmark):
        return self.cls_loss(gt_label, pred_label) \
               + self.box_loss(gt_label, gt_offset, pred_offset) \
               + self.landmark_loss(landmark_flag, gt_landmark, pred_landmark)

# %%
def visualize_accuracy(statistics, fig_name):
    sns.set(style="white")
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14,4))
    for phase,(loss,acc) in statistics.items():
        loss_hist = [float(h) for h in loss]
        acc_hist = [float(h) for h in acc]
        ax1.plot(np.arange(len(loss_hist)), loss_hist, label = phase)
        ax1.set(xlabel = 'Epochs', ylabel='total loss',title='total loss at the xth epoch');
        ax1.legend();
        ax2.plot(np.arange(len(acc_hist)), acc_hist, label = phase)
        ax2.set(xlabel = 'Epochs', ylabel='class loss',title='class loss at the xth epoch');
        ax2.legend();
    fig.show()
    fig.savefig(fig_name)

# %%
def train_Pnet(model, criterion, optimizer, loss_config, scheduler=None):
    
    train_begin = time.time()
    min_loss = 100.0
    best_model_wts = copy.deepcopy(model.state_dict())
    statistics = {'train':([],[]), 'eval':([],[])} # ([total loss],[class loss])
    

    for epoch in range(EPOCH):
        print('Epoch {}/{}'.format(epoch, EPOCH - 1))
        print('-' * 10)
        
        model.train()
        running_loss = 0.0
        running_cl = 0.0
        
        for (img_tensor, label, offset, landmark_flag, landmark) in P_trainLoader:
            
            
            wrap = (img_tensor, label, offset, landmark)
            (img_tensor, label, offset, landmark) = [i.cuda() for i in wrap]
            det, box, ldmk = model(img_tensor)
            if landmark==None:
                ldmk=None
            optimizer.zero_grad()
            all_loss = criterion.total_loss(gt_label=label, pred_label=det, gt_offset=offset, pred_offset=box,
                                       landmark_flag=landmark_flag, pred_landmark=ldmk, gt_landmark=landmark)
            cl_loss = criterion.cls_loss(gt_label=label, pred_label=det)

            all_loss.backward()
            optimizer.step()
            
            running_loss += all_loss.item() * img_tensor.size(0)
            running_cl += cl_loss.item() * img_tensor.size(0)
        epoch_loss = running_loss / P_trainSize
        epoch_cl_loss = running_cl / P_trainSize
        statistics['train'][0].append(epoch_loss)
        statistics['train'][1].append(epoch_cl_loss)
        if scheduler is not None:
            scheduler.step(epoch_loss)
            lr = optimizer.param_groups[0]['lr']
        print('Train Loss: {:.4f}  cl loss: {:.4f}  lr: {:.7f}'.format(epoch_loss, epoch_cl_loss, lr))
        
        
        with torch.no_grad():
            model.eval()
            running_loss = 0.0
            running_cl = 0.0

            for (img_tensor, label, offset, landmark_flag, landmark) in P_evalLoader:

                wrap = (img_tensor, label, offset, landmark)
                (img_tensor, label, offset, landmark) = [i.cuda() for i in wrap]
                det, box, ldmk = model(img_tensor)
                if landmark==None:
                    ldmk=None
                all_loss = criterion.total_loss(gt_label=label, pred_label=det, gt_offset=offset, pred_offset=box,
                                           landmark_flag=landmark_flag, pred_landmark=ldmk, gt_landmark=landmark)
                cl_loss = criterion.cls_loss(gt_label=label, pred_label=det)
                
                running_loss += all_loss.item() * img_tensor.size(0)
                running_cl += cl_loss.item() * img_tensor.size(0)
                
            epoch_loss = running_loss / P_evalSize
            epoch_cl_loss = running_cl / P_evalSize
            statistics['eval'][0].append(epoch_loss)
            statistics['eval'][1].append(epoch_cl_loss)
            print('Eval Loss: {:.4f}  cl loss: {:.4f}'.format(epoch_loss, epoch_cl_loss))
        print()
        
        
        if epoch_loss < min_loss:
            min_loss = epoch_loss
            best_model_wts = copy.deepcopy(model.state_dict())

    train_length = time.time() - train_begin
    print('Training complete in {:.0f}m {:.0f}s'.format(train_length // 60, train_length % 60))
    print('Min train loss: {:4f}'.format(min_loss))
    model.load_state_dict(best_model_wts)
    
    return model, statistics

# %% [markdown]
# ## assign paramaters and start training

# %%
global DEVICE
DEVICE = torch.device('cuda:0')
if torch.cuda.is_available():
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
else:
    torch.set_default_tensor_type('torch.FloatTensor')

    

LR = 0.001
EPOCH = 30
BATCH_SIZE = 32
NUM_WORKS = 8
Pnet_loss_config = [1.0, 0.5, 0.5]


P_trainset = PnetDataset('train', 5000)
P_trainLoader = DataLoader(P_trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKS, pin_memory=False)

P_evalset = PnetDataset('test', 500)
P_evalLoader = DataLoader(P_evalset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKS, pin_memory=False)

P_trainSize = len(P_trainset)
P_evalSize = len(P_evalset)
print(P_trainSize)
print(P_evalSize)


model = P_Net().cuda()
model.load_state_dict(torch.load('/kaggle/input/trainedmtcnn/PNet3.pth'))
for param in model.conv4_3.parameters():
    print(param.requires_grad)

    
optimizer = opt.Adam(model.parameters(), lr=LR, betas=(0.9, 0.999), eps=1e-08, amsgrad=True)
criterion = LossFn(cls_factor=Pnet_loss_config[0], box_factor=Pnet_loss_config[1], landmark_factor=Pnet_loss_config[2])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, 
        verbose=True, threshold=0.0001, threshold_mode='rel', cooldown=2, min_lr=1e-08, eps=1e-08)
# Out:
# 5000
# 500
# True
# True

# %%
model, statistics = train_Pnet(model, criterion, optimizer, Pnet_loss_config, scheduler)
# Out:
# Epoch 0/29
# ----------
# Train Loss: 0.1658  cl loss: 0.1353  lr: 0.0010000
# Eval Loss: 0.0988  cl loss: 0.0873
#
# Epoch 1/29
# ----------
# Train Loss: 0.0930  cl loss: 0.0839  lr: 0.0010000
# Eval Loss: 0.0735  cl loss: 0.0659
#
# Epoch 2/29
# ----------
# Train Loss: 0.0719  cl loss: 0.0653  lr: 0.0010000
# Eval Loss: 0.0943  cl loss: 0.0881
#
# Epoch 3/29
# ----------
# Train Loss: 0.0734  cl loss: 0.0678  lr: 0.0010000
# Eval Loss: 0.0558  cl loss: 0.0504
#
# Epoch 4/29
# ----------
# Train Loss: 0.0719  cl loss: 0.0670  lr: 0.0010000
# Eval Loss: 0.0523  cl loss: 0.0479
#
# Epoch 5/29
# ----------
# Train Loss: 0.0626  cl loss: 0.0580  lr: 0.0010000
# Eval Loss: 0.0518  cl loss: 0.0477
#
# Epoch 6/29
# ----------
# Train Loss: 0.0589  cl loss: 0.0547  lr: 0.0010000
# Eval Loss: 0.0507  cl loss: 0.0474
#
# Epoch 7/29
# ----------
# Train Loss: 0.0532  cl loss: 0.0495  lr: 0.0010000
# Eval Loss: 0.0461  cl loss: 0.0426
#
# Epoch 8/29
# ----------
# Train Loss: 0.0600  cl loss: 0.0563  lr: 0.0010000
# Eval Loss: 0.0614  cl loss: 0.0582
#
# Epoch 9/29
# ----------
# Train Loss: 0.0493  cl loss: 0.0457  lr: 0.0010000
# Eval Loss: 0.0485  cl loss: 0.0452
#
# Epoch 10/29
# ----------
# Train Loss: 0.0461  cl loss: 0.0428  lr: 0.0010000
# Eval Loss: 0.0406  cl loss: 0.0378
#
# Epoch 11/29
# ----------
# Train Loss: 0.0435  cl loss: 0.0406  lr: 0.0010000
# Eval Loss: 0.0529  cl loss: 0.0499
#
# Epoch 12/29
# ----------
# Train Loss: 0.0394  cl loss: 0.0364  lr: 0.0010000
# Eval Loss: 0.0375  cl loss: 0.0348
#
# Epoch 13/29
# ----------
# Train Loss: 0.0443  cl loss: 0.0415  lr: 0.0010000
# Eval Loss: 0.0434  cl loss: 0.0405
#
# Epoch 14/29
# ----------
# Train Loss: 0.0428  cl loss: 0.0399  lr: 0.0010000
# Eval Loss: 0.0426  cl loss: 0.0398
#
# Epoch 15/29
# ----------
# Train Loss: 0.0453  cl loss: 0.0425  lr: 0.0010000
# Eval Loss: 0.0328  cl loss: 0.0303
#
# Epoch 16/29
# ----------
# Train Loss: 0.0417  cl loss: 0.0392  lr: 0.0010000
# Eval Loss: 0.0363  cl loss: 0.0338
#
# Epoch 17/29
# ----------
# Train Loss: 0.0370  cl loss: 0.0345  lr: 0.0010000
# Eval Loss: 0.0418  cl loss: 0.0393
#
# Epoch 18/29
# ----------
# Train Loss: 0.0393  cl loss: 0.0369  lr: 0.0010000
# Eval Loss: 0.0169  cl loss: 0.0143
#
# Epoch 19/29
# ----------
# Train Loss: 0.0368  cl loss: 0.0343  lr: 0.0010000
# Eval Loss: 0.0233  cl loss: 0.0209
#
# Epoch 20/29
# ----------
# Train Loss: 0.0356  cl loss: 0.0332  lr: 0.0010000
# Eval Loss: 0.0156  cl loss: 0.0131
#
# Epoch 21/29
# ----------
# Train Loss: 0.0384  cl loss: 0.0360  lr: 0.0010000
# Eval Loss: 0.0383  cl loss: 0.0362
#
# Epoch 22/29
# ----------
# Train Loss: 0.0351  cl loss: 0.0327  lr: 0.0010000
# Eval Loss: 0.0383  cl loss: 0.0360
#
# Epoch 23/29
# ----------
# Train Loss: 0.0346  cl loss: 0.0323  lr: 0.0010000
# Eval Loss: 0.0310  cl loss: 0.0292
#
# Epoch 24/29
# ----------
# Train Loss: 0.0306  cl loss: 0.0283  lr: 0.0010000
# Eval Loss: 0.0261  cl loss: 0.0242
#
# Epoch 25/29
# ----------
# Train Loss: 0.0334  cl loss: 0.0311  lr: 0.0010000
# Eval Loss: 0.0293  cl loss: 0.0274
#
# Epoch 26/29
# ----------
# Train Loss: 0.0386  cl loss: 0.0361  lr: 0.0010000
# Eval Loss: 0.0198  cl loss: 0.0176
#
# Epoch 27/29
# ----------
# Train Loss: 0.0375  cl loss: 0.0353  lr: 0.0010000
# Eval Loss: 0.0389  cl loss: 0.0369
#
# Epoch 28/29
# ----------
# Train Loss: 0.0355  cl loss: 0.0333  lr: 0.0010000
# Eval Loss: 0.0427  cl loss: 0.0407
#
# Epoch 29/29
# ----------
# Train Loss: 0.0369  cl loss: 0.0348  lr: 0.0010000
# Eval Loss: 0.0269  cl loss: 0.0247
#
# Training complete in 17m 23s
# Min train loss: 0.015554

# %%
name = 'PNlm_1'
torch.save(model.state_dict(), '/kaggle/working/'+name+'.pth')
json.dump(statistics, open(name+'.json', 'w'))
visualize_accuracy(statistics, name)
