# %% [markdown]
# # Train FaceNet：ResNet18 with a 128-D embedding
#
# - Epoch: 120
# - LR: 0.005
# - Optimizer: Adam default
# - Batch size: 32
# - Margin: 0.5

# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
from torchvision import datasets, models, transforms
from torchvision.transforms import ToPILImage
import torchvision.transforms.functional as tf
import matplotlib.pyplot as plt
from torch.autograd import Variable
import pandas as pd
import seaborn as sns
from math import sqrt
from PIL import Image
import torch.utils.data as data
from torch.nn import functional as F
from sklearn.metrics import roc_curve, auc
from torch.utils.data import DataLoader
import time
import os
import math
import copy
import json
import random

# %%
def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True
setup_seed(20)

# %% [markdown]
# ## customized dataset
# All the people with more than 1 image available will be potential anchor, and this customized dataset has 1184 names of potential anchor for training and 496 for evaluation. In every epoch, a name is picked in order and two images of that person will be selected randomly, one as *anchor* and the other as *positive*. Then an image of other than that person will be selected randomly from the whole dataset and used as *negative*.

# %%
class IFWdataset(data.Dataset):
    
    def __init__(self, phase):
        
        self.endidx = {'train': 4037, 'test': 1710}.get(phase)
        self.root = '../input/lfwaligned/' + phase + '2/' + phase + '2'
        self.all_frame = pd.read_csv('../input/lfwaligned/people' + phase + '.csv')
        self.anc_frame = self.all_frame.loc[self.all_frame.images > 1]
        
        
    def __getitem__(self, index):
        
        anc_name, anc_img_num = self.anc_frame.iloc[index]
        anc_id, pos_id = random.sample(range(1, anc_img_num+1), 2)
        
        neg_name = anc_name
        while neg_name == anc_name:
            n = random.randint(0,self.endidx)
            neg_name, neg_img_num = self.all_frame.iloc[n]
        neg_id = random.randint(1,neg_img_num)
        
        
        anc = anc_name + '_' + ('000'+ str(anc_id))[-4:] + '.jpg'
        anc = Image.open(os.path.join(self.root,anc))
        anc = tf.resize(anc, (224,224))
        anc = transforms.RandomHorizontalFlip(p=0.5)(anc)
        anc = tf.to_tensor(anc)
        anc = tf.normalize(anc, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        
        pos = anc_name + '_' + ('000'+ str(pos_id))[-4:] + '.jpg'
        pos = Image.open(os.path.join(self.root,pos))
        pos = tf.resize(pos, (224,224))
        pos = transforms.RandomHorizontalFlip(p=0.5)(pos)
        pos = tf.to_tensor(pos)
        pos = tf.normalize(pos, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        
        neg = neg_name + '_' + ('000'+ str(neg_id))[-4:] + '.jpg'
        neg = Image.open(os.path.join(self.root,neg))
        neg = tf.resize(neg, (224,224))
        neg = transforms.RandomHorizontalFlip(p=0.5)(neg)
        neg = tf.to_tensor(neg)
        neg = tf.normalize(neg, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        
        return anc, pos, neg
   

    def __len__(self):
        return len(self.anc_frame) # train 1184, test 496

# %% [markdown]
# ## FaceNet = ResNet18 + 128D embedding
# 128D embedding = (128D Linear) + L2 norm + multiplied by 10

# %%
class FaceNet(nn.Module):
    def __init__(self):
        super(FaceNet, self).__init__()

        self.model = models.resnet18()
        self.model.fc = nn.Linear(25088, 128)

    def l2_norm(self,input):
        input_size = input.size()
        buffer = torch.pow(input, 2)
        normp = torch.sum(buffer, 1).add_(1e-10)
        norm = torch.sqrt(normp)
        _output = torch.div(input, norm.view(-1, 1).expand_as(input))
        output = _output.view(input_size)
        return output

    
    def forward(self, x):

        x = self.model.conv1(x)
        x = self.model.bn1(x)
        x = self.model.relu(x)
        x = self.model.maxpool(x)
        x = self.model.layer1(x)
        x = self.model.layer2(x)
        x = self.model.layer3(x)
        x = self.model.layer4(x)
        x = x.view(x.size(0), -1)
        x = self.model.fc(x)
        self.features = self.l2_norm(x)
        self.features = self.features * 10

        return self.features

# %%
def L2_distance(x1,x2):
    assert x1.size() == x2.size()
    eps = 1e-4 / x1.size(1)
    diff = torch.abs(x1 - x2)
    out = torch.pow(diff, 2).sum(dim=1)
    return torch.pow(out + eps, 1./2)


class TripletMarginLoss(nn.Module):
    def __init__(self, margin):
        super(TripletMarginLoss, self).__init__()
        self.margin = margin

    def forward(self, anchor, positive, negative):
        d_p = L2_distance(anchor, positive)
        d_n = L2_distance(anchor, negative)
        dist_hinge = F.relu(self.margin + d_p - d_n)
        loss = torch.mean(dist_hinge)
        return loss

# %%
import operator
from sklearn.model_selection import KFold
from scipy import interpolate

def evaluate(distances, labels, nrof_folds=10):
    thresholds=np.arange(0, 30, 0.01)
    nrof_pairs = min(len(labels), len(distances))
    nrof_thresholds = len(thresholds)
    k_fold = KFold(n_splits=nrof_folds, shuffle=False)

    tprs = np.zeros((nrof_folds,nrof_thresholds))
    fprs = np.zeros((nrof_folds,nrof_thresholds))
    accuracy = np.zeros((nrof_folds))

    indices = np.arange(nrof_pairs)

    for fold_idx, (train_set, test_set) in enumerate(k_fold.split(indices)):

        # Find the best threshold for the fold
        acc_train = np.zeros((nrof_thresholds))
        for threshold_idx, threshold in enumerate(thresholds):
            _, _, acc_train[threshold_idx] = calculate_accuracy(threshold, distances[train_set], labels[train_set])
        best_threshold_index = np.argmax(acc_train)
        for threshold_idx, threshold in enumerate(thresholds):
            tprs[fold_idx,threshold_idx], fprs[fold_idx,threshold_idx], _ = calculate_accuracy(threshold, distances[test_set], labels[test_set])
        _, _, accuracy[fold_idx] = calculate_accuracy(thresholds[best_threshold_index], distances[test_set], labels[test_set])

        tpr = np.mean(tprs,0)
        fpr = np.mean(fprs,0)
    accuracy = np.mean(accuracy)
    return tpr, fpr, accuracy


def calculate_accuracy(threshold, dist, actual_issame):
    predict_issame = np.less(dist, threshold)
    tp = np.sum(np.logical_and(predict_issame, actual_issame))
    fp = np.sum(np.logical_and(predict_issame, np.logical_not(actual_issame)))
    tn = np.sum(np.logical_and(np.logical_not(predict_issame), np.logical_not(actual_issame)))
    fn = np.sum(np.logical_and(np.logical_not(predict_issame), actual_issame))

    tpr = 0 if (tp+fn==0) else float(tp) / float(tp+fn)
    fpr = 0 if (fp+tn==0) else float(fp) / float(fp+tn)
    acc = float(tp+tn)/dist.size
    return tpr, fpr, acc

# %%
def visualize_accuracy(statistics, fig_name):
    sns.set(style="white")
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14,4))
    for phase,(loss,acc,other) in statistics.items():
        loss_hist = [float(h) for h in loss]
        acc_hist = [float(h) for h in acc]
        ax1.plot(np.arange(len(loss_hist)), loss_hist, label = phase)
        ax1.set(xlabel = 'epoch', ylabel='loss',title='loss at the xth epoch');
        ax1.legend();
        ax2.plot(np.arange(len(acc_hist)), acc_hist, label = phase)
        ax2.set(xlabel = 'epoch', ylabel='accuracy',title='accuracy at the xth epoch');
        ax2.legend();
    fig.savefig(fig_name)


def plot_roc(statistics,fig_name):
    fig = plt.figure()
    lw = 2
    fpr = statistics['train'][2][1]
    tpr = statistics['train'][2][2]
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color='r',
             lw=lw, label='train ROC (area = %0.2f)' % roc_auc)
    fpr, tpr = statistics['eval'][2]
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color='g',
             lw=lw, label='eval ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='black', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    fig.savefig(fig_name)
    
    
def plot_hardsmaple(statistics,fig_name):
    fig = plt.figure()
    y = statistics['train'][2][0]

    plt.plot(np.arange(len(y)), y)
    plt.xlabel('epoch')
    plt.ylabel('# train hard sample')
    plt.title('# train hardsample at the xth epoch')
    fig.savefig(fig_name)

# %%
def train_model(model, criterion, optimizer, scheduler=None):
    
    train_begin = time.time()
    min_loss = 100.0
    best_model_wts = copy.deepcopy(model.state_dict())
    statistics = {'train':[[],[],[[]]], 'eval':[[],[],[]]} # 'train':[[loss],[acc],[[#hard sample],[fpr],[tpr]]]  
                                                            # 'eval' :[[loss],[acc],[[fpr],[tpr]]]
    for epoch in range(1,EPOCH+1):
        print('Epoch {}/{}'.format(epoch, EPOCH))
        print('-' * 10)
        
        model.train()
        running_loss = 0.0
        trained_size = 0
        labels, distances = [], []
        
        for (anc, pos, neg) in trainLoader:
            
            wrap = (anc, pos, neg)
            (anc, pos, neg) = [i.cuda() for i in wrap]
            out_a, out_p, out_n = model(anc), model(pos), model(neg)
            
            d_p = L2_distance(out_a, out_p)
            d_n = L2_distance(out_a, out_n)

            keep = (d_n - d_p < MARGIN)
            hard_triplets = torch.where(keep == 1)[0]
            
            if len(hard_triplets) == 0:
                continue

            out_a_s = out_a[hard_triplets]
            out_p_s = out_p[hard_triplets]
            out_n_s = out_n[hard_triplets]
            
            trained_size += out_a_s.size(0)
            
            optimizer.zero_grad()
            triple_loss = criterion(out_a_s, out_p_s, out_n_s)

            triple_loss.backward()
            optimizer.step()
            
            running_loss += triple_loss.item() * out_a_s.size(0)
            
            dists = L2_distance(out_a,out_n)
            distances.append(dists.data.cpu().numpy())
            labels.append(np.zeros(dists.size(0)))

            dists = L2_distance(out_a,out_p)
            distances.append(dists.data.cpu().numpy())
            labels.append(np.ones(dists.size(0)))
        
    
        epoch_loss = running_loss / trained_size
        
        labels = np.array([sublabel for label in labels for sublabel in label])
        distances = np.array([subdist for dist in distances for subdist in dist])
        tpr, fpr, epoch_acc = evaluate(distances,labels)
        
        statistics['train'][0].append(epoch_loss)
        statistics['train'][1].append(epoch_acc)
        statistics['train'][2][0].append(out_a_s.size(0))
        if epoch==EPOCH:
            statistics['train'][2].append(list(fpr))
            statistics['train'][2].append(list(tpr))
        
        print('Train Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))
        
        
        with torch.no_grad():
            model.eval()
            running_loss = 0.0
            labels, distances = [], []

            for (anc, pos, neg) in evalLoader:

                wrap = (anc, pos, neg)
                (anc, pos, neg) = [i.cuda() for i in wrap]
                out_a, out_p, out_n = model(anc), model(pos), model(neg)
                
                triple_loss = criterion(out_a, out_p, out_n)
                running_loss += triple_loss.item() * anc.size(0)
                
                dists = L2_distance(out_a,out_n)
                distances.append(dists.data.cpu().numpy())
                labels.append(np.zeros(dists.size(0)))

                dists = L2_distance(out_a,out_p)
                distances.append(dists.data.cpu().numpy())
                labels.append(np.ones(dists.size(0)))

            epoch_loss = running_loss / evalSize
            labels = np.array([sublabel for label in labels for sublabel in label])
            distances = np.array([subdist for dist in distances for subdist in dist])
            tpr, fpr, epoch_acc = evaluate(distances,labels)
            
            statistics['eval'][0].append(epoch_loss)
            statistics['eval'][1].append(epoch_acc)
            if epoch==EPOCH:
                statistics['eval'][2]=[list(fpr),list(tpr)]
            print('Eval Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))
        print()
        
        if epoch_loss < min_loss:
            min_loss = epoch_loss
            best_model_wts = copy.deepcopy(model.state_dict())

    train_length = time.time() - train_begin
    print('Training complete in {:.0f}m {:.0f}s'.format(train_length // 60, train_length % 60))
    print('Min train loss: {:4f}'.format(min_loss))
    model.load_state_dict(best_model_wts)
    
    return model, statistics

# %% [markdown]
# ## assign parameters

# %%
global DEVICE
DEVICE = torch.device('cuda:0')
if torch.cuda.is_available():
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
else:
    torch.set_default_tensor_type('torch.FloatTensor')


LR = 0.005
EPOCH = 120
BATCH_SIZE = 32
NUM_WORKS = 8
MARGIN = 0.5

trainSet = IFWdataset('train')
trainLoader = DataLoader(trainSet, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKS, pin_memory=False)

evalSet = IFWdataset('test')
evalLoader = DataLoader(evalSet, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKS, pin_memory=False)

trainSize = len(trainSet)
evalSize = len(evalSet)
print(trainSize)
print(evalSize)

model = FaceNet().cuda()
optimizer = optim.Adam(model.parameters(), lr=LR, betas=(0.9, 0.999), eps=1e-08, amsgrad=True)
criterion = TripletMarginLoss(margin=MARGIN)
# Out:
# 1184
# 496

# %% [markdown]
# ## run and plot

# %%
model, statistics = train_model(model, criterion, optimizer, scheduler=None)
# Out:
# Epoch 1/120
# ----------
# Train Loss: 0.5977 Acc: 0.5553
# Eval Loss: 0.4619 Acc: 0.5010
#
# Epoch 2/120
# ----------
# Train Loss: 0.5587 Acc: 0.5828
# Eval Loss: 0.4191 Acc: 0.5898
#
# Epoch 3/120
# ----------
# Train Loss: 0.5354 Acc: 0.5904
# Eval Loss: 0.4048 Acc: 0.5636
#
# Epoch 4/120
# ----------
# Train Loss: 0.5584 Acc: 0.5853
# Eval Loss: 0.4208 Acc: 0.5786
#
# Epoch 5/120
# ----------
# Train Loss: 0.5562 Acc: 0.6288
# Eval Loss: 0.4660 Acc: 0.5061
#
# Epoch 6/120
# ----------
# Train Loss: 0.5471 Acc: 0.5963
# Eval Loss: 0.4106 Acc: 0.5555
#
# Epoch 7/120
# ----------
# Train Loss: 0.5401 Acc: 0.6161
# Eval Loss: 0.3922 Acc: 0.6098
#
# Epoch 8/120
# ----------
# Train Loss: 0.5258 Acc: 0.6343
# Eval Loss: 0.3432 Acc: 0.6541
#
# Epoch 9/120
# ----------
# Train Loss: 0.5252 Acc: 0.6343
# Eval Loss: 0.3656 Acc: 0.6321
#
# Epoch 10/120
# ----------
# Train Loss: 0.5392 Acc: 0.6195
# Eval Loss: 0.3817 Acc: 0.5898
#
# Epoch 11/120
# ----------
# Train Loss: 0.5256 Acc: 0.6571
# Eval Loss: 0.3487 Acc: 0.6603
#
# Epoch 12/120
# ----------
# Train Loss: 0.5182 Acc: 0.6563
# Eval Loss: 0.3362 Acc: 0.6432
#
# Epoch 13/120
# ----------
# Train Loss: 0.5455 Acc: 0.6377
# Eval Loss: 0.3385 Acc: 0.6259
#
# Epoch 14/120
# ----------
# Train Loss: 0.5130 Acc: 0.6651
# Eval Loss: 0.3687 Acc: 0.6180
#
# Epoch 15/120
# ----------
# Train Loss: 0.4906 Acc: 0.6432
# Eval Loss: 0.3096 Acc: 0.6594
#
# Epoch 16/120
# ----------
# Train Loss: 0.5281 Acc: 0.6732
# Eval Loss: 0.3231 Acc: 0.6190
#
# Epoch 17/120
# ----------
# Train Loss: 0.5165 Acc: 0.6664
# Eval Loss: 0.3446 Acc: 0.6431
#
# Epoch 18/120
# ----------
# Train Loss: 0.5162 Acc: 0.6778
# Eval Loss: 0.3309 Acc: 0.6504
#
# Epoch 19/120
# ----------
# Train Loss: 0.5260 Acc: 0.6824
# Eval Loss: 0.3309 Acc: 0.6633
#
# Epoch 20/120
# ----------
# Train Loss: 0.4997 Acc: 0.6732
# Eval Loss: 0.3125 Acc: 0.6462
#
# Epoch 21/120
# ----------
# Train Loss: 0.5152 Acc: 0.6791
# Eval Loss: 0.3011 Acc: 0.6773
#
# Epoch 22/120
# ----------
# Train Loss: 0.5095 Acc: 0.6976
# Eval Loss: 0.3436 Acc: 0.6260
#
# Epoch 23/120
# ----------
# Train Loss: 0.5187 Acc: 0.6867
# Eval Loss: 0.2999 Acc: 0.6855
#
# Epoch 24/120
# ----------
# Train Loss: 0.5098 Acc: 0.6968
# Eval Loss: 0.3126 Acc: 0.6562
#
# Epoch 25/120
# ----------
# Train Loss: 0.5163 Acc: 0.7141
# Eval Loss: 0.2836 Acc: 0.6743
#
# Epoch 26/120
# ----------
# Train Loss: 0.5271 Acc: 0.7056
# Eval Loss: 0.3087 Acc: 0.6301
#
# Epoch 27/120
# ----------
# Train Loss: 0.5028 Acc: 0.7099
# Eval Loss: 0.3139 Acc: 0.6835
#
# Epoch 28/120
# ----------
# Train Loss: 0.5150 Acc: 0.7141
# Eval Loss: 0.3259 Acc: 0.6523
#
# Epoch 29/120
# ----------
# Train Loss: 0.5039 Acc: 0.7268
# Eval Loss: 0.3099 Acc: 0.6946
#
# Epoch 30/120
# ----------
# Train Loss: 0.5236 Acc: 0.7069
# Eval Loss: 0.3068 Acc: 0.6673
#
# Epoch 31/120
# ----------
# Train Loss: 0.5007 Acc: 0.7403
# Eval Loss: 0.3102 Acc: 0.6573
#
# Epoch 32/120
# ----------
# Train Loss: 0.5134 Acc: 0.7209
# Eval Loss: 0.2894 Acc: 0.6834
#
# Epoch 33/120
# ----------
# Train Loss: 0.5304 Acc: 0.7074
# Eval Loss: 0.3186 Acc: 0.6814
#
# Epoch 34/120
# ----------
# Train Loss: 0.4881 Acc: 0.7264
# Eval Loss: 0.2809 Acc: 0.6875
#
# Epoch 35/120
# ----------
# Train Loss: 0.5249 Acc: 0.7390
# Eval Loss: 0.3325 Acc: 0.6473
#
# Epoch 36/120
# ----------
# Train Loss: 0.5121 Acc: 0.7242
# Eval Loss: 0.3121 Acc: 0.6774
#
# Epoch 37/120
# ----------
# Train Loss: 0.5349 Acc: 0.7344
# Eval Loss: 0.3012 Acc: 0.6884
#
# Epoch 38/120
# ----------
# Train Loss: 0.4921 Acc: 0.7407
# Eval Loss: 0.3101 Acc: 0.6765
#
# Epoch 39/120
# ----------
# Train Loss: 0.5293 Acc: 0.7319
# Eval Loss: 0.2739 Acc: 0.6864
#
# Epoch 40/120
# ----------
# Train Loss: 0.5497 Acc: 0.7331
# Eval Loss: 0.2834 Acc: 0.6663
#
# Epoch 41/120
# ----------
# Train Loss: 0.4806 Acc: 0.7597
# Eval Loss: 0.2409 Acc: 0.6805
#
# Epoch 42/120
# ----------
# Train Loss: 0.5099 Acc: 0.7437
# Eval Loss: 0.2980 Acc: 0.6764
#
# Epoch 43/120
# ----------
# Train Loss: 0.5137 Acc: 0.7411
# Eval Loss: 0.2864 Acc: 0.6885
#
# Epoch 44/120
# ----------
# Train Loss: 0.4984 Acc: 0.7724
# Eval Loss: 0.2736 Acc: 0.7037
#
# Epoch 45/120
# ----------
# Train Loss: 0.5182 Acc: 0.7344
# Eval Loss: 0.2414 Acc: 0.7046
#
# Epoch 46/120
# ----------
# Train Loss: 0.5055 Acc: 0.7715
# Eval Loss: 0.2782 Acc: 0.6846
#
# Epoch 47/120
# ----------
# Train Loss: 0.4921 Acc: 0.7572
# Eval Loss: 0.2533 Acc: 0.7066
#
# Epoch 48/120
# ----------
# Train Loss: 0.4911 Acc: 0.7589
# Eval Loss: 0.2830 Acc: 0.6633
#
# Epoch 49/120
# ----------
# Train Loss: 0.5248 Acc: 0.7640
# Eval Loss: 0.2420 Acc: 0.6987
#
# Epoch 50/120
# ----------
# Train Loss: 0.5205 Acc: 0.7715
# Eval Loss: 0.2886 Acc: 0.6915
#
# Epoch 51/120
# ----------
# Train Loss: 0.4978 Acc: 0.7584
# Eval Loss: 0.2642 Acc: 0.7117
#
# Epoch 52/120
# ----------
# Train Loss: 0.4913 Acc: 0.7686
# Eval Loss: 0.3120 Acc: 0.6511
#
# Epoch 53/120
# ----------
# Train Loss: 0.5181 Acc: 0.7614
# Eval Loss: 0.3233 Acc: 0.6633
#
# Epoch 54/120
# ----------
# Train Loss: 0.5634 Acc: 0.7521
# Eval Loss: 0.2586 Acc: 0.7147
#
# Epoch 55/120
# ----------
# Train Loss: 0.5212 Acc: 0.7855
# Eval Loss: 0.2496 Acc: 0.6915
#
# Epoch 56/120
# ----------
# Train Loss: 0.5113 Acc: 0.7504
# Eval Loss: 0.2376 Acc: 0.7239
#
# Epoch 57/120
# ----------
# Train Loss: 0.4775 Acc: 0.7703
# Eval Loss: 0.2746 Acc: 0.6986
#
# Epoch 58/120
# ----------
# Train Loss: 0.5190 Acc: 0.7664
# Eval Loss: 0.2773 Acc: 0.6714
#
# Epoch 59/120
# ----------
# Train Loss: 0.4994 Acc: 0.7627
# Eval Loss: 0.2805 Acc: 0.6895
#
# Epoch 60/120
# ----------
# Train Loss: 0.4968 Acc: 0.7808
# Eval Loss: 0.2695 Acc: 0.7248
#
# Epoch 61/120
# ----------
# Train Loss: 0.5512 Acc: 0.7745
# Eval Loss: 0.2426 Acc: 0.7067
#
# Epoch 62/120
# ----------
# Train Loss: 0.5371 Acc: 0.7732
# Eval Loss: 0.2615 Acc: 0.7087
#
# Epoch 63/120
# ----------
# Train Loss: 0.4974 Acc: 0.7838
# Eval Loss: 0.2605 Acc: 0.6976
#
# Epoch 64/120
# ----------
# Train Loss: 0.5319 Acc: 0.7745
# Eval Loss: 0.2397 Acc: 0.7198
#
# Epoch 65/120
# ----------
# Train Loss: 0.5099 Acc: 0.7926
# Eval Loss: 0.2658 Acc: 0.7258
#
# Epoch 66/120
# ----------
# Train Loss: 0.5060 Acc: 0.7842
# Eval Loss: 0.2533 Acc: 0.7248
#
# Epoch 67/120
# ----------
# Train Loss: 0.5036 Acc: 0.7758
# Eval Loss: 0.2716 Acc: 0.7107
#
# Epoch 68/120
# ----------
# Train Loss: 0.5130 Acc: 0.7876
# Eval Loss: 0.2750 Acc: 0.6907
#
# Epoch 69/120
# ----------
# Train Loss: 0.5188 Acc: 0.7804
# Eval Loss: 0.2339 Acc: 0.7177
#
# Epoch 70/120
# ----------
# Train Loss: 0.5073 Acc: 0.7981
# Eval Loss: 0.2262 Acc: 0.7289
#
# Epoch 71/120
# ----------
# Train Loss: 0.5608 Acc: 0.7838
# Eval Loss: 0.2805 Acc: 0.6704
#
# Epoch 72/120
# ----------
# Train Loss: 0.4847 Acc: 0.7829
# Eval Loss: 0.2765 Acc: 0.6804
#
# Epoch 73/120
# ----------
# Train Loss: 0.5292 Acc: 0.8032
# Eval Loss: 0.2269 Acc: 0.7269
#
# Epoch 74/120
# ----------
# Train Loss: 0.5251 Acc: 0.7990
# Eval Loss: 0.2545 Acc: 0.6996
#
# Epoch 75/120
# ----------
# Train Loss: 0.5456 Acc: 0.7977
# Eval Loss: 0.2583 Acc: 0.6905
#
# Epoch 76/120
# ----------
# Train Loss: 0.5184 Acc: 0.8070
# Eval Loss: 0.2591 Acc: 0.7269
#
# Epoch 77/120
# ----------
# Train Loss: 0.5033 Acc: 0.8116
# Eval Loss: 0.2369 Acc: 0.7208
#
# Epoch 78/120
# ----------
# Train Loss: 0.5335 Acc: 0.8045
# Eval Loss: 0.2658 Acc: 0.6855
#
# Epoch 79/120
# ----------
# Train Loss: 0.5294 Acc: 0.8091
# Eval Loss: 0.2483 Acc: 0.6724
#
# Epoch 80/120
# ----------
# Train Loss: 0.5138 Acc: 0.7977
# Eval Loss: 0.2638 Acc: 0.7116
#
# Epoch 81/120
# ----------
# Train Loss: 0.4979 Acc: 0.8116
# Eval Loss: 0.2734 Acc: 0.7177
#
# Epoch 82/120
# ----------
# Train Loss: 0.5649 Acc: 0.8036
# Eval Loss: 0.2087 Acc: 0.7188
#
# Epoch 83/120
# ----------
# Train Loss: 0.5388 Acc: 0.7986
# Eval Loss: 0.2485 Acc: 0.7319
#
# Epoch 84/120
# ----------
# Train Loss: 0.5046 Acc: 0.8028
# Eval Loss: 0.2087 Acc: 0.7217
#
# Epoch 85/120
# ----------
# Train Loss: 0.4915 Acc: 0.8036
# Eval Loss: 0.2240 Acc: 0.7117
#
# Epoch 86/120
# ----------
# Train Loss: 0.5807 Acc: 0.8023
# Eval Loss: 0.2976 Acc: 0.6754
#
# Epoch 87/120
# ----------
# Train Loss: 0.5211 Acc: 0.7872
# Eval Loss: 0.2503 Acc: 0.6946
#
# Epoch 88/120
# ----------
# Train Loss: 0.4954 Acc: 0.8121
# Eval Loss: 0.2535 Acc: 0.7137
#
# Epoch 89/120
# ----------
# Train Loss: 0.5621 Acc: 0.7977
# Eval Loss: 0.2800 Acc: 0.7118
#
# Epoch 90/120
# ----------
# Train Loss: 0.5319 Acc: 0.8193
# Eval Loss: 0.2071 Acc: 0.7429
#
# Epoch 91/120
# ----------
# Train Loss: 0.5008 Acc: 0.8239
# Eval Loss: 0.2193 Acc: 0.7299
#
# Epoch 92/120
# ----------
# Train Loss: 0.4676 Acc: 0.8230
# Eval Loss: 0.2461 Acc: 0.7299
#
# Epoch 93/120
# ----------
# Train Loss: 0.5439 Acc: 0.8053
# Eval Loss: 0.2349 Acc: 0.7168
#
# Epoch 94/120
# ----------
# Train Loss: 0.4840 Acc: 0.8252
# Eval Loss: 0.2109 Acc: 0.7157
#
# Epoch 95/120
# ----------
# Train Loss: 0.5343 Acc: 0.8095
# Eval Loss: 0.2361 Acc: 0.7047
#
# Epoch 96/120
# ----------
# Train Loss: 0.4973 Acc: 0.8243
# Eval Loss: 0.2289 Acc: 0.7016
#
# Epoch 97/120
# ----------
# Train Loss: 0.5146 Acc: 0.8319
# Eval Loss: 0.2809 Acc: 0.6886
#
# Epoch 98/120
# ----------
# Train Loss: 0.4860 Acc: 0.8108
# Eval Loss: 0.2512 Acc: 0.7259
#
# Epoch 99/120
# ----------
# Train Loss: 0.5454 Acc: 0.8201
# Eval Loss: 0.2487 Acc: 0.7308
#
# Epoch 100/120
# ----------
# Train Loss: 0.5290 Acc: 0.8056
# Eval Loss: 0.2303 Acc: 0.7238
#
# Epoch 101/120
# ----------
# Train Loss: 0.5191 Acc: 0.8362
# Eval Loss: 0.2258 Acc: 0.7207
#
# Epoch 102/120
# ----------
# Train Loss: 0.4856 Acc: 0.8214
# Eval Loss: 0.2454 Acc: 0.7036
#
# Epoch 103/120
# ----------
# Train Loss: 0.5643 Acc: 0.8290
# Eval Loss: 0.2430 Acc: 0.7007
#
# Epoch 104/120
# ----------
# Train Loss: 0.5052 Acc: 0.8197
# Eval Loss: 0.2370 Acc: 0.7298
#
# Epoch 105/120
# ----------
# Train Loss: 0.5110 Acc: 0.8201
# Eval Loss: 0.2818 Acc: 0.7179
#
# Epoch 106/120
# ----------
# Train Loss: 0.5452 Acc: 0.8229
# Eval Loss: 0.2199 Acc: 0.7309
#
# Epoch 107/120
# ----------
# Train Loss: 0.5438 Acc: 0.8171
# Eval Loss: 0.2616 Acc: 0.7480
#
# Epoch 108/120
# ----------
# Train Loss: 0.5578 Acc: 0.8176
# Eval Loss: 0.2455 Acc: 0.7218
#
# Epoch 109/120
# ----------
# Train Loss: 0.4892 Acc: 0.8332
# Eval Loss: 0.2249 Acc: 0.7420
#
# Epoch 110/120
# ----------
# Train Loss: 0.5083 Acc: 0.8231
# Eval Loss: 0.2271 Acc: 0.7198
#
# Epoch 111/120
# ----------
# Train Loss: 0.5735 Acc: 0.8353
# Eval Loss: 0.2066 Acc: 0.7360
#
# Epoch 112/120
# ----------
# Train Loss: 0.5593 Acc: 0.8361
# Eval Loss: 0.2519 Acc: 0.7076
#
# Epoch 113/120
# ----------
# Train Loss: 0.5223 Acc: 0.8246
# Eval Loss: 0.2305 Acc: 0.7388
#
# Epoch 114/120
# ----------
# Train Loss: 0.5004 Acc: 0.8325
# Eval Loss: 0.2332 Acc: 0.7400
#
# Epoch 115/120
# ----------
# Train Loss: 0.5520 Acc: 0.8197
# Eval Loss: 0.2249 Acc: 0.7319
#
# Epoch 116/120
# ----------
# Train Loss: 0.5178 Acc: 0.8366
# Eval Loss: 0.2228 Acc: 0.7490
#
# Epoch 117/120
# ----------
# Train Loss: 0.5747 Acc: 0.8315
# Eval Loss: 0.2063 Acc: 0.7298
#
# Epoch 118/120
# ----------
# Train Loss: 0.5100 Acc: 0.8446
# Eval Loss: 0.1936 Acc: 0.7641
#
# Epoch 119/120
# ----------
# Train Loss: 0.5228 Acc: 0.8551
# Eval Loss: 0.2345 Acc: 0.7166
#
# Epoch 120/120
# ----------
# Train Loss: 0.5151 Acc: 0.8442
# Eval Loss: 0.2378 Acc: 0.7208
#
# Training complete in 52m 1s
# Min train loss: 0.193600

# %%
name = 'FN_res18_120'
torch.save(model.state_dict(), '/kaggle/working/'+name+'.pth')
json.dump(statistics, open(name+'.json', 'w'))
visualize_accuracy(statistics, name+'.png')
plot_roc(statistics,name+'_auc.png')

# %%
plot_hardsmaple(statistics,name+'_#hard.png')
