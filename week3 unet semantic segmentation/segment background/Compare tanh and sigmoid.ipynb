# %%
# %matplotlib inline

# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
from torchvision import datasets, models, transforms
from torchvision.transforms import ToPILImage
import torchvision.transforms.functional as tf
import matplotlib.pyplot as plt
import seaborn as sns
from math import sqrt
from PIL import Image
from torch.utils import data
import time
import math
import os
import copy
import json
import random

# %%
def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
def pad_to_square(img):
    s = img.size
    w = abs((s[0]-max(s))//2)
    h = abs((s[1]-max(s))//2)
    padding = (w,h,max(s)-s[0]-w,max(s)-s[1]-h)
    return tf.pad(img, padding)

# %%
def Train_transform_sigmoid(image,mask,tanh=False,aug=True):
    image = pad_to_square(image)
    mask = pad_to_square(mask)
    image = tf.resize(image, (224,224))
    mask = tf.resize(mask, (224,224))

    if aug:
        if random.random() > 0.5:
            image = tf.hflip(image)
            mask = tf.hflip(mask)
        if random.random() > 0.5:
            image = tf.vflip(image)
            mask = tf.vflip(mask)
        image = tf.adjust_contrast(image,random.uniform(0.7,1.3))
        image = tf.adjust_brightness(image,random.uniform(0.7,1.3))
    
    image = tf.to_tensor(image)
    mask = (np.array(mask)>0).astype(np.float32)
    if tanh:
        mask = mask*2-1
    mask = tf.to_tensor(mask)
    image = tf.normalize(image, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    return image, mask

def Eval_transform_sigmoid(image,mask):
    return Train_transform_sigmoid(image,mask,False,False)

def Train_transform_tanh(image,mask):
    return Train_transform_sigmoid(image,mask,True,True)

def Eval_transform_tanh(image,mask):
    return Train_transform_sigmoid(image,mask,True,False)

transform = {
    'sigmoid':{'train': Train_transform_sigmoid, 'eval': Eval_transform_sigmoid},
    'tanh':{'train': Train_transform_tanh, 'eval': Eval_transform_tanh}
}

# %%
class LIPDataset(data.Dataset):
    
    def __init__(self, root=None, img_path=None, mask_path=None, num_images=300, transform=None, start=0):   
        
        self.root = root
        self.img_path = img_path
        self.mask_path = mask_path
        self.transform = transform        
        self.images = []
        self.masks = []
        c = 0
        for step,name in enumerate(list(sorted(os.listdir(os.path.join(root,img_path))))):
            if step < start:
                continue
                
            if c == num_images:
                break
            im = os.path.join(root,img_path,name)
            ma = os.path.join(root,mask_path,name[:-4]+'.png')
            if self.is_valid_image(im) and self.is_valid_image(ma):
                self.images.append(im)
                self.masks.append(ma)
                c+=1
            else:
                print('img and mask failed to be opened:')
                print(im)
                print(ma)
        
    def is_valid_image(self, path):
        try:
            i = Image.open(path)
            valid = True
        except:
            valid = False
        return valid
        
    def __getitem__(self, idx):
        
        image = Image.open(self.images[idx]).convert('RGB')
        mask = Image.open(self.masks[idx])
        if self.transform:
            image, mask = self.transform(image,mask)
        return image, mask
   
    def __len__(self):
        return len(self.images)

# %%
def load_data(TRAIN_BS, num_train, num_eval):
    dic = {'root': '/kaggle/input/singleperson', 
                'train': ('TrainVal_images/TrainVal_images/train_images',
                          'TrainVal_parsing_annotations/TrainVal_parsing_annotations/TrainVal_parsing_annotations/train_segmentations',
                          num_train),
                'eval': ('TrainVal_images/TrainVal_images/val_images',
                         'TrainVal_parsing_annotations/TrainVal_parsing_annotations/TrainVal_parsing_annotations/val_segmentations',
                         num_eval)
               }
    datasets = {x: LIPDataset(dic['root'], dic[x][0], dic[x][1], dic[x][2], transform[ACT][x], start=0) for x in ['train', 'eval']}
    dataset_sizes = {x: len(datasets[x]) for x in ['train', 'eval']}
    print(dataset_sizes)
    dataloaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=TRAIN_BS, shuffle=True, num_workers=4) for x in ['train','eval']}
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print(device)
    return datasets, dataloaders, dataset_sizes, device

# %%
def imshow(phase):
    print(phase + ' images:')
    imgs, masks = next(iter(dataloaders[phase]))
    im = torchvision.utils.make_grid(imgs)
    im = im.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    im = std * im + mean
    plt.imshow(im);
    plt.pause(0.001)
    ma = torchvision.utils.make_grid(masks)
    ma = ma.numpy().transpose((1, 2, 0))
    plt.imshow(ma);
    plt.pause(0.001)

# %%
class conv_block(nn.Module):
    def __init__(self,ch_in,ch_out):
        super(conv_block,self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(ch_in, ch_out, kernel_size=3,stride=1,padding=1,bias=True),
            nn.BatchNorm2d(ch_out),
            nn.ReLU(inplace=True),
            nn.Conv2d(ch_out, ch_out, kernel_size=3,stride=1,padding=1,bias=True),
            nn.BatchNorm2d(ch_out),
            nn.ReLU(inplace=True)
        )
    def forward(self,x):
        x = self.conv(x)
        return x

    
class up_conv(nn.Module):
    def __init__(self,ch_in,ch_out):
        super(up_conv,self).__init__()
        self.up = nn.Sequential(
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.Conv2d(ch_in,ch_out,kernel_size=1,stride=1,padding=0,bias=True),
            nn.BatchNorm2d(ch_out),
            nn.ReLU(inplace=True)
        )
    def forward(self,x):
        x = self.up(x)
        return x

    
class UNet(nn.Module):
    def __init__(self, act=None):
        super(UNet,self).__init__()
        
        self.act = act
        
        self.Maxpool = nn.MaxPool2d(kernel_size=2,stride=2)

        self.Conv1 = conv_block(ch_in=3,ch_out=64)
        self.Conv2 = conv_block(ch_in=64,ch_out=128)
        self.Conv3 = conv_block(ch_in=128,ch_out=256)
        self.Conv4 = conv_block(ch_in=256,ch_out=512)
        self.Conv5 = conv_block(ch_in=512,ch_out=1024)

        self.Up5 = up_conv(ch_in=1024,ch_out=512)
        self.Up_conv5 = conv_block(ch_in=1024, ch_out=512)

        self.Up4 = up_conv(ch_in=512,ch_out=256)
        self.Up_conv4 = conv_block(ch_in=512, ch_out=256)
        
        self.Up3 = up_conv(ch_in=256,ch_out=128)
        self.Up_conv3 = conv_block(ch_in=256, ch_out=128)
        
        self.Up2 = up_conv(ch_in=128,ch_out=64)
        self.Up_conv2 = conv_block(ch_in=128, ch_out=64)

        self.Conv_1x1 = nn.Conv2d(64,1,kernel_size=1,stride=1,padding=0)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d): 
                n = m.kernel_size[0] * m.kernel_size[1] * m.in_channels
                m.weight.data.normal_(0, sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_() 
    
    def forward(self,x):
        x1 = self.Conv1(x)

        x2 = self.Maxpool(x1)
        x2 = self.Conv2(x2)
        
        x3 = self.Maxpool(x2)
        x3 = self.Conv3(x3)

        x4 = self.Maxpool(x3)
        x4 = self.Conv4(x4)

        x5 = self.Maxpool(x4)
        x5 = self.Conv5(x5)

        d5 = self.Up5(x5)
        d5 = torch.cat((x4,d5),dim=1)
        
        d5 = self.Up_conv5(d5)
        
        d4 = self.Up4(d5)
        d4 = torch.cat((x3,d4),dim=1)
        d4 = self.Up_conv4(d4)

        d3 = self.Up3(d4)
        d3 = torch.cat((x2,d3),dim=1)
        d3 = self.Up_conv3(d3)

        d2 = self.Up2(d3)
        d2 = torch.cat((x1,d2),dim=1)
        d2 = self.Up_conv2(d2)

        d1 = self.Conv_1x1(d2)
        
        if self.act =='tanh':
            return nn.Tanh()(d1)
        elif self.act == 'sigmoid':
            return nn.Sigmoid()(d1)

# %%
def mIOU(pred,target):
    batch_accs = 0.0
    for img in range(pred.size(0)):
        pred_inds = pred[img,0,:,:] == 1
        target_inds = target[img,0,:,:] == 1
        intersection = (pred_inds[target_inds]).sum()
        union = pred_inds.sum() + target_inds.sum() - intersection
        batch_accs += float(intersection)/float(max(union,1))
    return batch_accs


def train_model(model, criterion, optimizer, num_epochs, scheduler=None):
    since = time.time()
    
    statistics = {'train':([],[]), 'eval':([],[])} # train:(loss,acc), test:(loss,acc)
    lrs = []
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    iters = len(dataloaders['train'])
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        for phase in ['train', 'eval']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_accs = 0.0
                      
            for step,(inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)
                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    o = outputs.cuda().data.cpu().numpy()
                    preds = torch.tensor((o>threshold).astype(np.float32)).to(device)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        lrs.append((step, optimizer.param_groups[0]['lr']))
                        loss.backward()
                        optimizer.step()
                        if scheduler is not None:
                            scheduler.step(epoch + step / iters)
                        
                running_loss += loss.item() * inputs.size(0)
                running_accs += mIOU(preds,labels)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_accs / dataset_sizes[phase]
            
            statistics[phase][0].append(epoch_loss)
            statistics[phase][1].append(epoch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            if phase == 'eval' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
        
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best eval Acc: {:4f}'.format(best_acc))

    return model, statistics, lrs, inputs, labels, preds, outputs

# %%
def visualize_accuracy(num_epochs, statistics, fig_name):
    sns.set(style="white")
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14,4))
    for phase,(loss,acc) in statistics.items():
        loss_hist = [float(h) for h in loss]
        acc_hist = [float(h) for h in acc]
        ax1.plot(np.arange(len(loss_hist)), loss_hist, label = phase)
        ax1.set(xlabel = 'Epochs', ylabel='loss',title='loss at the xth epoch');
        ax1.legend();
        ax2.plot(np.arange(len(acc_hist)), acc_hist, label = phase)
        ax2.set(xlabel = 'Epochs', ylabel='accuracy',title='accuracy at the xth epoch');
        ax2.legend();
    fig.savefig(fig_name)

# %%
def get_fixed_imgs():
    data_dir = {'root': '/kaggle/input/singleperson', 
            'train': ('TrainVal_images/TrainVal_images/train_images',
                      'TrainVal_parsing_annotations/TrainVal_parsing_annotations/TrainVal_parsing_annotations/train_segmentations'),
            'eval': ('TrainVal_images/TrainVal_images/val_images',
                     'TrainVal_parsing_annotations/TrainVal_parsing_annotations/TrainVal_parsing_annotations/val_segmentations')
           }
    phases = ['train','eval']   
    demo = {x: LIPDataset(data_dir['root'], data_dir[x][0], data_dir[x][1], 8, transform[ACT]['eval']) for x in phases}
    demo_loader= {x: torch.utils.data.DataLoader(demo[x], batch_size=8, shuffle=False) for x in phases}
    dic = {x:{} for x in phases}
    for phase in phases:
        inputs, labels = next(iter(demo_loader[phase]))
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        o = outputs.cuda().data.cpu().numpy()
        preds = torch.tensor((o>threshold).astype(np.float32)).to(device)
        dic[phase]['images'] = inputs
        dic[phase]['masks'] = labels
        dic[phase]['outputs'] = outputs
        dic[phase]['preds'] = preds
    return dic


def visualize_performance(dic):
    fig = plt.figure()
    for keys,values in dic.items():
        print('Several images in ' + keys + ':')
        for k,v in values.items():
            im = torchvision.utils.make_grid(v[:8,:,:,:], nrow=4)
            im = im.cuda().data.cpu().numpy().transpose((1, 2, 0))
            if k == 'images':
                mean = np.array([0.485, 0.456, 0.406])
                std = np.array([0.229, 0.224, 0.225])
                im = std * im + mean
            plt.imshow(im);
            plt.title(k)
            plt.pause(0.001)
    fig.show()

# %% [markdown]
# ## tanh

# %%
ACT, threshold =  'tanh', 0.0

setup_seed(20)
datasets, dataloaders, dataset_sizes, device = load_data(32,1500,500)
imshow('train')

model = UNet(ACT)
model = model.to(device)
print(model.act)
num_epochs = 70

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

model, statistics, lrs, inputs, labels, preds, outputs = train_model(model, criterion, optimizer, num_epochs, scheduler=None)

name = 'UN_1500_70e_tanh'

json.dump(statistics, open(name+'.json', 'w'))
visualize_accuracy(num_epochs, statistics, name+'.png')
visualize_performance(get_fixed_imgs())
torch.save(model.state_dict(), '/kaggle/working/'+name+'.pth')
# Out:
# {'train': 1500, 'eval': 500}
# cuda:0
# train images:
# tanh
# Epoch 0/69
# ----------
# train Loss: 0.6706 Acc: 0.3536
# eval Loss: 0.5344 Acc: 0.4486
#
# Epoch 1/69
# ----------
# train Loss: 0.5636 Acc: 0.4358
# eval Loss: 0.8069 Acc: 0.3841
#
# Epoch 2/69
# ----------
# train Loss: 0.5351 Acc: 0.4781
# eval Loss: 0.4726 Acc: 0.5035
#
# Epoch 3/69
# ----------
# train Loss: 0.5175 Acc: 0.4967
# eval Loss: 0.9617 Acc: 0.3359
#
# Epoch 4/69
# ----------
# train Loss: 0.5026 Acc: 0.5141
# eval Loss: 0.4387 Acc: 0.5525
#
# Epoch 5/69
# ----------
# train Loss: 0.5024 Acc: 0.5114
# eval Loss: 0.9617 Acc: 0.3582
#
# Epoch 6/69
# ----------
# train Loss: 0.4864 Acc: 0.5288
# eval Loss: 0.6812 Acc: 0.4196
#
# Epoch 7/69
# ----------
# train Loss: 0.4816 Acc: 0.5350
# eval Loss: 0.4285 Acc: 0.5708
#
# Epoch 8/69
# ----------
# train Loss: 0.4762 Acc: 0.5394
# eval Loss: 0.8659 Acc: 0.3398
#
# Epoch 9/69
# ----------
# train Loss: 0.4656 Acc: 0.5473
# eval Loss: 0.8046 Acc: 0.4279
#
# Epoch 10/69
# ----------
# train Loss: 0.4610 Acc: 0.5519
# eval Loss: 0.3816 Acc: 0.5569
#
# Epoch 11/69
# ----------
# train Loss: 0.4488 Acc: 0.5658
# eval Loss: 0.5238 Acc: 0.5275
#
# Epoch 12/69
# ----------
# train Loss: 0.4384 Acc: 0.5756
# eval Loss: 0.3847 Acc: 0.5958
#
# Epoch 13/69
# ----------
# train Loss: 0.4330 Acc: 0.5830
# eval Loss: 0.3648 Acc: 0.5997
#
# Epoch 14/69
# ----------
# train Loss: 0.4276 Acc: 0.5854
# eval Loss: 0.3846 Acc: 0.6044
#
# Epoch 15/69
# ----------
# train Loss: 0.4234 Acc: 0.5904
# eval Loss: 0.3491 Acc: 0.6162
#
# Epoch 16/69
# ----------
# train Loss: 0.4174 Acc: 0.5958
# eval Loss: 0.3518 Acc: 0.6331
#
# Epoch 17/69
# ----------
# train Loss: 0.4141 Acc: 0.5998
# eval Loss: 0.3892 Acc: 0.6017
#
# Epoch 18/69
# ----------
# train Loss: 0.4029 Acc: 0.6081
# eval Loss: 0.3348 Acc: 0.6185
#
# Epoch 19/69
# ----------
# train Loss: 0.3964 Acc: 0.6142
# eval Loss: 0.3461 Acc: 0.5911
#
# Epoch 20/69
# ----------
# train Loss: 0.3931 Acc: 0.6161
# eval Loss: 0.5023 Acc: 0.5829
#
# Epoch 21/69
# ----------
# train Loss: 0.3854 Acc: 0.6261
# eval Loss: 0.3571 Acc: 0.6427
#
# Epoch 22/69
# ----------
# train Loss: 0.3869 Acc: 0.6232
# eval Loss: 0.3933 Acc: 0.5690
#
# Epoch 23/69
# ----------
# train Loss: 0.3792 Acc: 0.6297
# eval Loss: 0.3268 Acc: 0.6562
#
# Epoch 24/69
# ----------
# train Loss: 0.3751 Acc: 0.6333
# eval Loss: 0.3465 Acc: 0.5928
#
# Epoch 25/69
# ----------
# train Loss: 0.3664 Acc: 0.6440
# eval Loss: 0.3120 Acc: 0.6634
#
# Epoch 26/69
# ----------
# train Loss: 0.3597 Acc: 0.6528
# eval Loss: 0.3222 Acc: 0.6592
#
# Epoch 27/69
# ----------
# train Loss: 0.3589 Acc: 0.6522
# eval Loss: 0.3081 Acc: 0.6258
#
# Epoch 28/69
# ----------
# train Loss: 0.3545 Acc: 0.6530
# eval Loss: 0.3150 Acc: 0.6350
#
# Epoch 29/69
# ----------
# train Loss: 0.3464 Acc: 0.6598
# eval Loss: 0.3048 Acc: 0.6824
#
# Epoch 30/69
# ----------
# train Loss: 0.3382 Acc: 0.6682
# eval Loss: 0.3612 Acc: 0.6471
#
# Epoch 31/69
# ----------
# train Loss: 0.3415 Acc: 0.6634
# eval Loss: 0.2857 Acc: 0.6710
#
# Epoch 32/69
# ----------
# train Loss: 0.3365 Acc: 0.6696
# eval Loss: 0.3004 Acc: 0.6721
#
# Epoch 33/69
# ----------
# train Loss: 0.3325 Acc: 0.6702
# eval Loss: 0.2961 Acc: 0.6660
#
# Epoch 34/69
# ----------
# train Loss: 0.3276 Acc: 0.6767
# eval Loss: 0.3518 Acc: 0.6625
#
# Epoch 35/69
# ----------
# train Loss: 0.3266 Acc: 0.6751
# eval Loss: 0.7907 Acc: 0.4562
#
# Epoch 36/69
# ----------
# train Loss: 0.3215 Acc: 0.6813
# eval Loss: 0.3042 Acc: 0.6887
#
# Epoch 37/69
# ----------
# train Loss: 0.3204 Acc: 0.6821
# eval Loss: 0.2851 Acc: 0.6739
#
# Epoch 38/69
# ----------
# train Loss: 0.3177 Acc: 0.6836
# eval Loss: 0.5559 Acc: 0.5098
#
# Epoch 39/69
# ----------
# train Loss: 0.3170 Acc: 0.6829
# eval Loss: 0.2878 Acc: 0.6954
#
# Epoch 40/69
# ----------
# train Loss: 0.3110 Acc: 0.6901
# eval Loss: 0.2834 Acc: 0.6741
#
# Epoch 41/69
# ----------
# train Loss: 0.3039 Acc: 0.6919
# eval Loss: 0.2755 Acc: 0.6962
#
# Epoch 42/69
# ----------
# train Loss: 0.3091 Acc: 0.6877
# eval Loss: 0.3026 Acc: 0.6837
#
# Epoch 43/69
# ----------
# train Loss: 0.3001 Acc: 0.6982
# eval Loss: 0.2996 Acc: 0.6737
#
# Epoch 44/69
# ----------
# train Loss: 0.2948 Acc: 0.6997
# eval Loss: 0.2679 Acc: 0.6911
#
# Epoch 45/69
# ----------
# train Loss: 0.2933 Acc: 0.7018
# eval Loss: 0.2874 Acc: 0.6509
#
# Epoch 46/69
# ----------
# train Loss: 0.2913 Acc: 0.7021
# eval Loss: 0.2696 Acc: 0.6996
#
# Epoch 47/69
# ----------
# train Loss: 0.2929 Acc: 0.7008
# eval Loss: 0.3124 Acc: 0.6935
#
# Epoch 48/69
# ----------
# train Loss: 0.2866 Acc: 0.7087
# eval Loss: 0.3460 Acc: 0.6817
#
# Epoch 49/69
# ----------
# train Loss: 0.2824 Acc: 0.7094
# eval Loss: 0.2805 Acc: 0.6967
#
# Epoch 50/69
# ----------
# train Loss: 0.2856 Acc: 0.7094
# eval Loss: 0.3130 Acc: 0.6660
#
# Epoch 51/69
# ----------
# train Loss: 0.2879 Acc: 0.7063
# eval Loss: 0.2668 Acc: 0.6972
#
# Epoch 52/69
# ----------
# train Loss: 0.2766 Acc: 0.7164
# eval Loss: 0.2734 Acc: 0.6904
#
# Epoch 53/69
# ----------
# train Loss: 0.2703 Acc: 0.7204
# eval Loss: 0.2744 Acc: 0.6947
#
# Epoch 54/69
# ----------
# train Loss: 0.2651 Acc: 0.7239
# eval Loss: 0.2812 Acc: 0.6897
#
# Epoch 55/69
# ----------
# train Loss: 0.2649 Acc: 0.7231
# eval Loss: 0.2712 Acc: 0.6875
#
# Epoch 56/69
# ----------
# train Loss: 0.2667 Acc: 0.7229
# eval Loss: 0.2592 Acc: 0.7006
#
# Epoch 57/69
# ----------
# train Loss: 0.2597 Acc: 0.7290
# eval Loss: 0.2665 Acc: 0.7081
#
# Epoch 58/69
# ----------
# train Loss: 0.2615 Acc: 0.7258
# eval Loss: 0.2657 Acc: 0.6969
#
# Epoch 59/69
# ----------
# train Loss: 0.2524 Acc: 0.7335
# eval Loss: 0.2696 Acc: 0.7031
#
# Epoch 60/69
# ----------
# train Loss: 0.2505 Acc: 0.7363
# eval Loss: 0.2829 Acc: 0.6672
#
# Epoch 61/69
# ----------
# train Loss: 0.2484 Acc: 0.7356
# eval Loss: 0.2748 Acc: 0.7038
#
# Epoch 62/69
# ----------
# train Loss: 0.2438 Acc: 0.7397
# eval Loss: 0.2629 Acc: 0.7013
#
# Epoch 63/69
# ----------
# train Loss: 0.2422 Acc: 0.7402
# eval Loss: 0.3236 Acc: 0.6498
#
# Epoch 64/69
# ----------
# train Loss: 0.2366 Acc: 0.7456
# eval Loss: 0.2864 Acc: 0.6743
#
# Epoch 65/69
# ----------
# train Loss: 0.2347 Acc: 0.7469
# eval Loss: 0.2787 Acc: 0.7095
#
# Epoch 66/69
# ----------
# train Loss: 0.2385 Acc: 0.7435
# eval Loss: 0.2724 Acc: 0.6973
#
# Epoch 67/69
# ----------
# train Loss: 0.2279 Acc: 0.7544
# eval Loss: 0.2722 Acc: 0.6992
#
# Epoch 68/69
# ----------
# train Loss: 0.2287 Acc: 0.7532
# eval Loss: 0.2680 Acc: 0.6993
#
# Epoch 69/69
# ----------
# train Loss: 0.2237 Acc: 0.7551
# eval Loss: 0.2759 Acc: 0.7045
#
# Training complete in 80m 15s
# Best eval Acc: 0.709471
# Several images in train:
# Several images in eval:

# %% [markdown]
# ## sigmoid

# %%
ACT, threshold =  'sigmoid', 0.5

setup_seed(20)
datasets, dataloaders, dataset_sizes, device = load_data(32,1500,500)
imshow('train')

model = UNet(ACT)
model = model.to(device)
print(model.act)
num_epochs = 70

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

model, statistics, lrs, inputs, labels, preds, outputs = train_model(model, criterion, optimizer, num_epochs, scheduler=None)

name = 'UN_1500_70e_sigmoid'

json.dump(statistics, open(name+'.json', 'w'))
visualize_accuracy(num_epochs, statistics, name+'.png')
visualize_performance(get_fixed_imgs())
torch.save(model.state_dict(), '/kaggle/working/'+name+'.pth')
# Out:
# {'train': 1500, 'eval': 500}
# cuda:0
# train images:
# sigmoid
# Epoch 0/69
# ----------
# train Loss: 0.1579 Acc: 0.3946
# eval Loss: 0.2724 Acc: 0.2861
#
# Epoch 1/69
# ----------
# train Loss: 0.1388 Acc: 0.4554
# eval Loss: 0.1776 Acc: 0.3343
#
# Epoch 2/69
# ----------
# train Loss: 0.1337 Acc: 0.4843
# eval Loss: 0.1175 Acc: 0.5230
#
# Epoch 3/69
# ----------
# train Loss: 0.1274 Acc: 0.5047
# eval Loss: 0.1069 Acc: 0.5361
#
# Epoch 4/69
# ----------
# train Loss: 0.1241 Acc: 0.5223
# eval Loss: 0.1368 Acc: 0.5245
#
# Epoch 5/69
# ----------
# train Loss: 0.1241 Acc: 0.5185
# eval Loss: 0.1058 Acc: 0.5460
#
# Epoch 6/69
# ----------
# train Loss: 0.1194 Acc: 0.5385
# eval Loss: 0.2783 Acc: 0.2651
#
# Epoch 7/69
# ----------
# train Loss: 0.1176 Acc: 0.5507
# eval Loss: 0.1021 Acc: 0.5685
#
# Epoch 8/69
# ----------
# train Loss: 0.1154 Acc: 0.5490
# eval Loss: 0.0961 Acc: 0.5538
#
# Epoch 9/69
# ----------
# train Loss: 0.1153 Acc: 0.5546
# eval Loss: 0.0962 Acc: 0.5936
#
# Epoch 10/69
# ----------
# train Loss: 0.1119 Acc: 0.5691
# eval Loss: 0.0964 Acc: 0.5771
#
# Epoch 11/69
# ----------
# train Loss: 0.1105 Acc: 0.5751
# eval Loss: 0.0903 Acc: 0.5955
#
# Epoch 12/69
# ----------
# train Loss: 0.1071 Acc: 0.5867
# eval Loss: 0.0896 Acc: 0.5924
#
# Epoch 13/69
# ----------
# train Loss: 0.1054 Acc: 0.5927
# eval Loss: 0.0886 Acc: 0.5905
#
# Epoch 14/69
# ----------
# train Loss: 0.1032 Acc: 0.5983
# eval Loss: 0.1095 Acc: 0.5821
#
# Epoch 15/69
# ----------
# train Loss: 0.1035 Acc: 0.5998
# eval Loss: 0.0846 Acc: 0.6296
#
# Epoch 16/69
# ----------
# train Loss: 0.1019 Acc: 0.6053
# eval Loss: 0.0849 Acc: 0.6310
#
# Epoch 17/69
# ----------
# train Loss: 0.1010 Acc: 0.6093
# eval Loss: 0.0952 Acc: 0.5776
#
# Epoch 18/69
# ----------
# train Loss: 0.0980 Acc: 0.6187
# eval Loss: 0.0820 Acc: 0.6457
#
# Epoch 19/69
# ----------
# train Loss: 0.0962 Acc: 0.6240
# eval Loss: 0.0795 Acc: 0.6227
#
# Epoch 20/69
# ----------
# train Loss: 0.0953 Acc: 0.6273
# eval Loss: 0.1113 Acc: 0.6227
#
# Epoch 21/69
# ----------
# train Loss: 0.0945 Acc: 0.6314
# eval Loss: 0.0868 Acc: 0.6521
#
# Epoch 22/69
# ----------
# train Loss: 0.0946 Acc: 0.6315
# eval Loss: 0.0821 Acc: 0.6059
#
# Epoch 23/69
# ----------
# train Loss: 0.0925 Acc: 0.6393
# eval Loss: 0.0798 Acc: 0.6500
#
# Epoch 24/69
# ----------
# train Loss: 0.0918 Acc: 0.6413
# eval Loss: 0.0870 Acc: 0.6324
#
# Epoch 25/69
# ----------
# train Loss: 0.0908 Acc: 0.6484
# eval Loss: 0.0735 Acc: 0.6700
#
# Epoch 26/69
# ----------
# train Loss: 0.0891 Acc: 0.6533
# eval Loss: 0.0762 Acc: 0.6709
#
# Epoch 27/69
# ----------
# train Loss: 0.0871 Acc: 0.6583
# eval Loss: 0.0749 Acc: 0.6542
#
# Epoch 28/69
# ----------
# train Loss: 0.0872 Acc: 0.6571
# eval Loss: 0.0790 Acc: 0.6334
#
# Epoch 29/69
# ----------
# train Loss: 0.0856 Acc: 0.6631
# eval Loss: 0.0814 Acc: 0.6725
#
# Epoch 30/69
# ----------
# train Loss: 0.0840 Acc: 0.6669
# eval Loss: 0.0818 Acc: 0.6663
#
# Epoch 31/69
# ----------
# train Loss: 0.0837 Acc: 0.6673
# eval Loss: 0.0781 Acc: 0.6793
#
# Epoch 32/69
# ----------
# train Loss: 0.0823 Acc: 0.6754
# eval Loss: 0.0758 Acc: 0.6756
#
# Epoch 33/69
# ----------
# train Loss: 0.0829 Acc: 0.6712
# eval Loss: 0.0754 Acc: 0.6612
#
# Epoch 34/69
# ----------
# train Loss: 0.0826 Acc: 0.6707
# eval Loss: 0.0821 Acc: 0.6745
#
# Epoch 35/69
# ----------
# train Loss: 0.0806 Acc: 0.6770
# eval Loss: 0.0765 Acc: 0.6722
#
# Epoch 36/69
# ----------
# train Loss: 0.0795 Acc: 0.6837
# eval Loss: 0.0796 Acc: 0.6847
#
# Epoch 37/69
# ----------
# train Loss: 0.0796 Acc: 0.6835
# eval Loss: 0.0697 Acc: 0.6780
#
# Epoch 38/69
# ----------
# train Loss: 0.0784 Acc: 0.6866
# eval Loss: 0.0706 Acc: 0.6776
#
# Epoch 39/69
# ----------
# train Loss: 0.0776 Acc: 0.6855
# eval Loss: 0.0935 Acc: 0.6920
#
# Epoch 40/69
# ----------
# train Loss: 0.0765 Acc: 0.6955
# eval Loss: 0.0704 Acc: 0.6560
#
# Epoch 41/69
# ----------
# train Loss: 0.0757 Acc: 0.6921
# eval Loss: 0.0683 Acc: 0.6887
#
# Epoch 42/69
# ----------
# train Loss: 0.0762 Acc: 0.6922
# eval Loss: 0.0710 Acc: 0.6986
#
# Epoch 43/69
# ----------
# train Loss: 0.0741 Acc: 0.7014
# eval Loss: 0.0753 Acc: 0.6765
#
# Epoch 44/69
# ----------
# train Loss: 0.0729 Acc: 0.7037
# eval Loss: 0.0679 Acc: 0.6887
#
# Epoch 45/69
# ----------
# train Loss: 0.0735 Acc: 0.7019
# eval Loss: 0.0733 Acc: 0.6885
#
# Epoch 46/69
# ----------
# train Loss: 0.0719 Acc: 0.7029
# eval Loss: 0.0678 Acc: 0.6794
#
# Epoch 47/69
# ----------
# train Loss: 0.0715 Acc: 0.7074
# eval Loss: 0.1122 Acc: 0.5975
#
# Epoch 48/69
# ----------
# train Loss: 0.0700 Acc: 0.7094
# eval Loss: 0.0677 Acc: 0.6843
#
# Epoch 49/69
# ----------
# train Loss: 0.0693 Acc: 0.7149
# eval Loss: 0.0669 Acc: 0.7006
#
# Epoch 50/69
# ----------
# train Loss: 0.0688 Acc: 0.7161
# eval Loss: 0.0745 Acc: 0.6678
#
# Epoch 51/69
# ----------
# train Loss: 0.0712 Acc: 0.7069
# eval Loss: 0.0668 Acc: 0.6974
#
# Epoch 52/69
# ----------
# train Loss: 0.0678 Acc: 0.7189
# eval Loss: 0.0818 Acc: 0.6134
#
# Epoch 53/69
# ----------
# train Loss: 0.0687 Acc: 0.7173
# eval Loss: 0.0662 Acc: 0.7034
#
# Epoch 54/69
# ----------
# train Loss: 0.0658 Acc: 0.7234
# eval Loss: 0.0690 Acc: 0.6970
#
# Epoch 55/69
# ----------
# train Loss: 0.0663 Acc: 0.7190
# eval Loss: 0.0672 Acc: 0.6862
#
# Epoch 56/69
# ----------
# train Loss: 0.0652 Acc: 0.7279
# eval Loss: 0.0763 Acc: 0.6943
#
# Epoch 57/69
# ----------
# train Loss: 0.0626 Acc: 0.7349
# eval Loss: 0.0728 Acc: 0.6965
#
# Epoch 58/69
# ----------
# train Loss: 0.0642 Acc: 0.7277
# eval Loss: 0.0678 Acc: 0.6945
#
# Epoch 59/69
# ----------
# train Loss: 0.0633 Acc: 0.7329
# eval Loss: 0.0729 Acc: 0.6905
#
# Epoch 60/69
# ----------
# train Loss: 0.0620 Acc: 0.7375
# eval Loss: 0.0677 Acc: 0.6697
#
# Epoch 61/69
# ----------
# train Loss: 0.0620 Acc: 0.7356
# eval Loss: 0.0676 Acc: 0.6966
#
# Epoch 62/69
# ----------
# train Loss: 0.0606 Acc: 0.7415
# eval Loss: 0.0669 Acc: 0.7062
#
# Epoch 63/69
# ----------
# train Loss: 0.0597 Acc: 0.7422
# eval Loss: 0.0781 Acc: 0.6937
#
# Epoch 64/69
# ----------
# train Loss: 0.0597 Acc: 0.7434
# eval Loss: 0.0704 Acc: 0.6937
#
# Epoch 65/69
# ----------
# train Loss: 0.0581 Acc: 0.7495
# eval Loss: 0.0650 Acc: 0.7102
#
# Epoch 66/69
# ----------
# train Loss: 0.0574 Acc: 0.7523
# eval Loss: 0.0681 Acc: 0.6982
#
# Epoch 67/69
# ----------
# train Loss: 0.0573 Acc: 0.7522
# eval Loss: 0.0684 Acc: 0.6964
#
# Epoch 68/69
# ----------
# train Loss: 0.0555 Acc: 0.7587
# eval Loss: 0.0680 Acc: 0.7123
#
# Epoch 69/69
# ----------
# train Loss: 0.0561 Acc: 0.7569
# eval Loss: 0.0676 Acc: 0.7042
#
# Training complete in 80m 14s
# Best eval Acc: 0.712323
# Several images in train:
# Several images in eval:

# %% [markdown]
# <img src='Compare activation.png' width='450' height='300'>
